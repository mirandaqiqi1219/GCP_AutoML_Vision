# %% [markdown]
# <a href="https://colab.research.google.com/github/mirandaqiqi1219/GCP_AutoML_Vision/blob/master/GCP_AutoML_Vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##GCP AutoML Vision

# %% [markdown]
# ###ingest data

# %%
from IPython.display import Image

# %%
Image("ingest_data.png", width=700)

# %%
#take a lot of data size for each category of flower
Image("data_size.png", width=500)

# %% [markdown]
# ###Modeling

# %%
#model precision
Image("model_precision.png", width=800)

# %%
#model output confusion matrix
Image("confusion_matrix.png", width=700)

# %% [markdown]
# ###Predict with new model

# %%
#test1
Image("test1_result.png", width=700)

# %%
#test2
Image("test2_result.png", width=700)

# %%
#test3
Image("test3_result.png", width=700)

# %%
#test4
Image("test4_result.png", width=700)

# %%
#test5
Image("test5_result.png", width=700)

# %% [markdown]
# ##Predict with Vision API

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !export GOOGLE_APPLICATION_CREDENTIALS="/content/gdrive/My\ Drive/vision-973b04e0b0bf.json"
# !gcloud auth activate-service-account --key-file /content/gdrive/My\ Drive/vision-973b04e0b0bf.json
# !pip install --upgrade -q google-cloud-vision
# Out:
# Activated service account credentials for: [flower-case@vision-232900.iam.gserviceaccount.com]

# %%
import io
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="/content/gdrive/My Drive/vision-973b04e0b0bf.json"

# Imports the Google Cloud client library
from google.cloud import vision
from google.cloud.vision import types

# Instantiates a client
client = vision.ImageAnnotatorClient()

# The name of the image file to annotate
file_name = 'test1.jpg'

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# Flower
# Rose
# Garden roses
# Flowering plant
# Petal
# Red
# Plant
# Floribunda
# Rose family
# Hybrid tea rose

# %%
#test2
file_name = 'test2.jpg'

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# Flower
# Flowering plant
# Petal
# Tulip
# Plant
# Leaf
# Yellow
# Spring
# Plant stem
# Natural environment

# %%
#test3
file_name = 'test3.jpg'

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# People in nature
# Green
# Photograph
# Spring
# Hand
# Dandelion
# Flower
# Grass
# Water
# Leaf

# %%
#test4
file_name = 'test4.jpg'

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# Skin
# Nail
# Hand
# Petal
# Finger
# Flower
# Manicure
# Plant
# Gesture
# Smile

# %%
#test5
file_name = 'test5.jpg'

# Loads the image into memory
with io.open(file_name, 'rb') as image_file:
    content = image_file.read()

image = types.Image(content=content)

# Performs label detection on the image file
response = client.label_detection(image=image)
labels = response.label_annotations

print('Labels:')
for label in labels:
    print(label.description)
# Out:
# Labels:
# Sunflower
# People in nature
# Yellow
# Flower
# sunflower
# Field
# Plant
# Sky
# Happy
# Summer
